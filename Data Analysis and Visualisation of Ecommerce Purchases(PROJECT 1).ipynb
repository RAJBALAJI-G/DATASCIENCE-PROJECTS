# %% [markdown]
# # Analysing Ecommerce Purchase using Pandas

# %%
import pandas as pd

# %% [markdown]
# # Load Dataset

# %%
df = df = pd.read_csv("Ecommerce Purchases")
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# # Rename the column AM or PM to Time

# %%
df.rename({'AM or PM': 'Time'},axis=1,inplace=True)
df
# Out:
#                                                 Address    Lot Time  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in   PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn   PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE   PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm   PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE   AM
# ...                                                 ...    ...  ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI   PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY   AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh   AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL   PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr   AM
#
#                                            Browser Info  \
# 0     Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# ...

# %% [markdown]
# # Shape of the Dataset

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# # Datatypes in the Dataset

# %%
df.dtypes
# Out:
# Address              object
# Lot                  object
# Time                 object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   Time              10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# # View the first 10 rows of the data

# %%
df.head(10)
# Out:
#                                              Address    Lot Time  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in   PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn   PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE   PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm   PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE   AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT   PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt   AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG   PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN   PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug   AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# ...

# %% [markdown]
# # View the last 10 rows of the data

# %%
df.tail(10)
# Out:
#                                                 Address    Lot Time  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty   PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA   AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH   PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg   PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex   PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI   PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY   AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh   AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL   PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr   AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# # Check for empty values

# %%
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# Time                0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# # Display the number of Rows

# %%
len(df)
# Out:
# 10000

# %% [markdown]
# # Display the number of Columns

# %%
len(df.columns)
# Out:
# 14

# %% [markdown]
# # Max Purchase Price

# %%
df['Purchase Price'].max()
# Out:
# 99.99

# %% [markdown]
# # Minimum Purchase Price

# %%
df['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# # Average Purchase Prices

# %%
df['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %% [markdown]
# # Languages available in the dataset

# %%
df.Language.unique()
# Out:
# array(['el', 'fr', 'de', 'es', 'ru', 'pt', 'zh', 'en', 'it'], dtype=object)

# %% [markdown]
# # Count the no of values in the column

# %%
df.Language.value_counts()
# Out:
# de    1155
# ru    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: Language, dtype: int64

# %% [markdown]
# # Plot it in the Dataset

# %%
df.Language.value_counts().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Mean of Purchase Price per Language

# %%
df.groupby('Language')['Purchase Price'].mean()
# Out:
# Language
# de    50.254485
# el    51.555356
# en    51.103015
# es    49.366977
# fr    49.476718
# it    50.001004
# pt    51.215546
# ru    49.927134
# zh    50.180198
# Name: Purchase Price, dtype: float64

# %% [markdown]
# # Language Barplot

# %%
df.groupby('Language')['Purchase Price'].mean().plot.bar(figsize=(8,5))
# Out:
# <AxesSubplot:xlabel='Language'>

# %% [markdown]
# # Number of people speaking English

# %%
df.Language.value_counts().loc["en"]
# Out:
# 1098

# %% [markdown]
#  # Data of People speaking English

# %%
endf=df[df["Language"]=="en"]
endf
# Out:
#                                                 Address    Lot Time  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK   PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO   AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa   PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND   AM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh   PM
# ...                                                 ...    ...  ...
# 9961        714 Joshua Ridges\nCarpenterville, NJ 37418  84 rK   PM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo   AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt   PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN   PM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK   PM
#
#                                            Browser Info  \
# 11    Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
# ...

# %% [markdown]
# # Count of People Speaking English working as Surgeon

# %%
endf.Job.value_counts().loc["Surgeon"]
# Out:
# 2

# %% [markdown]
# # Data of People Speaking English working as Surgeon

# %%
endf[endf['Job'].str.contains('Surgeon')]
# Out:
#                                                 Address    Lot Time  \
# 952      78520 Holland Bypass\nBriantown, GU 39033-4260  27 al   PM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo   AM
#
#                                            Browser Info  \
# 952   Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...
# 9963  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like M...
#
#                           Company       Credit Card CC Exp Date  \
# 952   Mitchell, Gibbs and Freeman    30596378487665       02/25
# 9963      Brown, Gentry and White  4295151255424068       07/25
#
#       CC Security Code                  CC Provider                 Email  \
# 952                196  Diners Club / Carte Blanche  fjohnson@hotmail.com
# 9963               764                 JCB 15 digit      zjames@gmail.com
#
#           Job      IP Address Language  Purchase Price
# 952   Surgeon  54.209.243.183       en           76.22
# ...

# %% [markdown]
# # Count of People working as Drilling engineer

# %%
df.Job.value_counts().loc["Drilling engineer"]
# Out:
# 21

# %% [markdown]
# # Data of People  working as Drilling engineer

# %%
df[df["Job"]=="Drilling engineer"]
# Out:
#                                                 Address    Lot Time  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn   PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm   PM
# 779               PSC 9956, Box 2820\nAPO AE 81969-8768  14 yG   PM
# 1104  32038 Adams Valley Suite 436\nNorth Kaylachest...  44 eL   AM
# 1303  98753 Smith Radial Suite 963\nSouth Jasmine, R...  45 cj   AM
# 1531                   PSC 7147, Box 5613\nAPO AE 35453  76 Cs   AM
# 2989  98274 Henderson Expressway Suite 475\nPort Hay...  32 Ls   PM
# 3558  01333 Nicholas Hill Suite 739\nEast Maria, DE ...  45 tj   AM
# 3753  96370 Shannon Isle Apt. 581\nRandallton, PA 62...  05 cD   PM
# 4840  031 Lang Plaza\nLake Matthewchester, NE 79519-...  13 DM   PM
# 4969   5865 Wendy Square\nNew Jacqueline, SD 40769-9181  02 JU   PM
# 4981                   PSC 9130, Box 5382\nAPO AP 58279  36 MU   PM
# 5604  0633 Diane Manors Suite 038\nKristinafort, MA ...  70 sb   AM
# ...

# %% [markdown]
# # Job Title contains Dancer

# %%
df['Job']=='Dancer'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Job, Length: 10000, dtype: bool

# %% [markdown]
# # Count of Dancers

# %%
df.Job.value_counts().loc["Dancer"]
# Out:
# 14

# %% [markdown]
# # Data of Dancers

# %%
df[df['Job']=='Dancer']
# Out:
#                                                 Address    Lot Time  \
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt   AM
# 872          716 Wendy Corner\nGouldport, RI 81873-9167  82 ZU   AM
# 1256     54064 Wheeler Flat\nSchmidtland, NH 87134-6222  76 fW   PM
# 1760      656 Anthony Radial\nJoechester, OR 53771-4000  10 EY   PM
# 2317    16552 Rachel Meadows\nThomasview, VT 18408-6920  53 ez   PM
# 5268     101 Williams Vista\nLake Joseph, AR 18702-4805  61 GN   AM
# 5684  58625 Leon Drive Suite 169\nWest Austinville, ...  08 YP   PM
# 6491     576 Patterson Coves\nWillisfurt, NV 13824-3515  05 vF   AM
# 7566        1177 Reyes Parkway\nSouth Bradley, DE 26248  14 Bd   PM
# 8100  59819 Juan Stravenue Suite 174\nHopkinsborough...  80 hg   PM
# 8987              Unit 7130 Box 0011\nDPO AP 52644-0262  87 wd   PM
# 9051           256 Vaughn Flats\nRaymondburgh, LA 52916  22 sD   AM
# 9254  26256 Copeland Ramp Suite 581\nJaredchester, S...  39 xe   AM
# ...

# %%
df['Job'].describe()
# Out:
# count                             10000
# unique                              623
# top       Interior and spatial designer
# freq                                 31
# Name: Job, dtype: object

# %%
df.Job.value_counts().loc["Drilling engineer"]
# Out:
# 21

# %% [markdown]
# # Finding The Email of the person with Maestro Cards

# %%
df[df['CC Provider'] == 'Maestro']
# Out:
#                                                 Address    Lot Time  \
# 20        7383 George Village\nLake Jamesview, CO 79828  23 dk   PM
# 29    30755 Joshua Plaza Apt. 567\nWest Susanton, FM...  93 OP   PM
# 47    261 Walton Road Suite 704\nMaldonadoshire, MD ...  55 DV   PM
# 57    80728 Anthony Common Apt. 128\nNorth Rebecca, ...  50 Cq   PM
# 83    907 Williams Fork\nPort Alexanderport, NY 6534...  16 Kw   AM
# ...                                                 ...    ...  ...
# 9958                   PSC 8781, Box 4214\nAPO AP 94478  72 Ez   AM
# 9966        433 Jeffrey Plain\nEast Troy, LA 47554-8117  18 gm   AM
# 9984       7560 Boyle Keys\nAntoniomouth, DC 00522-0367  72 Qb   AM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg   PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex   PM
#
#                                            Browser Info  \
# 20    Mozilla/5.0 (Windows; U; Windows NT 4.0) Apple...
# ...

# %%
df[df['CC Provider'] == 'Maestro']['Email']
# Out:
# 20         zstephenson@smith.info
# 29           stonekaren@yahoo.com
# 47               zrocha@glenn.org
# 57           timothy88@morris.com
# 83           amberramos@yahoo.com
#                   ...
# 9958       reynoldsrick@yahoo.com
# 9966           jeff10@hotmail.com
# 9984        clee@vasquez-luna.com
# 9993    chelseawilliams@lopez.biz
# 9994           iroberts@gmail.com
# Name: Email, Length: 846, dtype: object

# %% [markdown]
# # People with JCB 16 digit as their Credit Card Provider and made a purchase above 60

# %%
df[df['CC Provider']=='JCB 16 digit']
# Out:
#                                                 Address    Lot Time  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in   PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE   PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN   PM
# 21    282 Miller Valleys Suite 404\nWilkinsonbury, M...  24 RZ   AM
# 32                     Unit 3628 Box 6778\nDPO AE 72362  39 Qm   PM
# ...                                                 ...    ...  ...
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK   PM
# 9982  18044 Mcintosh Row Apt. 122\nLake Jennifer, NC...  77 uq   PM
# 9983              PSC 5678, Box 4503\nAPO AP 94998-5546  79 cd   AM
# 9986  2719 Troy Drive Suite 062\nLisachester, PW 414...  80 Wl   PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY   AM
#
#                                            Browser Info  \
# 0     Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# ...

# %%
df[(df['CC Provider']=='JCB 16 digit')&(df['Purchase Price']>60)]
# Out:
#                                                 Address    Lot Time  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in   PM
# 21    282 Miller Valleys Suite 404\nWilkinsonbury, M...  24 RZ   AM
# 70                Unit 9635 Box 0238\nDPO AE 55910-7730  76 NA   PM
# 81              36971 Carrillo Fall\nAlanfurt, VI 30447  01 sd   PM
# 109   6863 James Circles Apt. 776\nGabrielfort, DE 6...  80 WW   PM
# ...                                                 ...    ...  ...
# 9899     29507 Amy Park Apt. 848\nLake Eugene, VT 64134  34 HW   AM
# 9931  71958 Diaz Roads Apt. 343\nPort Richardville, ...  62 qP   AM
# 9955      66539 Potts Forge\nCartershire, AK 58271-5180  37 KB   AM
# 9964  28035 Stewart Landing Suite 399\nWellsland, TX...  14 Ey   AM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL   AM
#
#                                            Browser Info  \
# 0     Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# ...

# %%
len(df[(df['CC Provider']=='JCB 16 digit')&(df['Purchase Price']>60)])
# Out:
# 670

# %% [markdown]
# # email of the person with specific Company

# %%
df[df['Company']=='Fowler Inc' ]
# Out:
#                                     Address    Lot Time  \
# 81  36971 Carrillo Fall\nAlanfurt, VI 30447  01 sd   PM
#
#                                          Browser Info     Company  \
# 81  Mozilla/5.0 (compatible; MSIE 6.0; Windows CE;...  Fowler Inc
#
#          Credit Card CC Exp Date  CC Security Code   CC Provider  \
# 81  3096082589629929       05/21               464  JCB 16 digit
#
#                    Email                       Job      IP Address Language  \
# 81  emilygreen@yahoo.com  Print production planner  172.64.177.225       it
#
#     Purchase Price
# 81           60.69

# %%
df[df['Company']=='Fowler Inc' ]['Email']
# Out:
# 81    emilygreen@yahoo.com
# Name: Email, dtype: object

# %% [markdown]
# # Purchases during AM and PM

# %%
df['Time'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: Time, dtype: int64

# %% [markdown]
# # credit card that expires in 2025

# %%
df['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
#Split the date wih'/' as delimiter and count
def expiry():
    count=0
    for d in df['CC Exp Date']:
        if d.split('/')[1]=='25':
            count=count+1
    print(count)

# %%
expiry()
# Out:
# 1033

# %% [markdown]
# # Display the Top email providers in the dataset

# %%
df['Email']
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
emaillist=[]
for email in df['Email']:
    emaillist.append(email.split('@')[1])
#print(emaillist)

# %%
df['email_provider']=emaillist

# %%
df['email_provider'].value_counts()
# Out:
# hotmail.com            1638
# yahoo.com              1616
# gmail.com              1605
# smith.com                42
# williams.com             37
#                        ...
# booker.com                1
# woods-allen.biz           1
# richards-wilson.com       1
# morris-thomas.com         1
# wade-garner.com           1
# Name: email_provider, Length: 3416, dtype: int64

# %%
df['email_provider'].value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: email_provider, dtype: int64
