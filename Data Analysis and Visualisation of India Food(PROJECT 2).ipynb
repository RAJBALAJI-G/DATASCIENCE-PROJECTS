# %% [markdown]
# # Data Analysis and Visualisation of India Food

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = df = pd.read_csv("indian_food.csv")
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %% [markdown]
# # To display the list of columns

# %%
df.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='object')

# %% [markdown]
# # To print the first 10 rows in the dataset

# %%
df.head(10)
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          diet  prep_time  cook_time flavor_profile   course          state  \
# 0  vegetarian         45         25          sweet  dessert    West Bengal
# ...

# %% [markdown]
# # T0 print the last 10 rows in the dataset

# %%
df.tail(10)
# Out:
#                   name                                        ingredients  \
# 245         Pani Pitha  Tea leaves, white sesame seeds, dry coconut, s...
# 246             Payokh  Basmati rice, rose water, sugar, clarified but...
# 247  Prawn malai curry      Coconut milk, prawns, garlic, turmeric, sugar
# 248           Red Rice  Red pepper, red onion, butter, watercress, oli...
# 249             Shukto  Green beans, bitter gourd, ridge gourd, banana...
# 250          Til Pitha            Glutinous rice, black sesame seeds, gur
# 251            Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252             Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253          Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254             Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 245      vegetarian         10         20             -1  main course
# ...

# %% [markdown]
# # Display the data types of each column

# %%
df.dtypes
# Out:
# name              object
# ingredients       object
# diet              object
# prep_time          int64
# cook_time          int64
# flavor_profile    object
# course            object
# state             object
# region            object
# dtype: object

# %% [markdown]
# # Check for empty values

# %%
df.isnull()
# Out:
#       name  ingredients   diet  prep_time  cook_time  flavor_profile  course  \
# 0    False        False  False      False      False           False   False
# 1    False        False  False      False      False           False   False
# 2    False        False  False      False      False           False   False
# 3    False        False  False      False      False           False   False
# 4    False        False  False      False      False           False   False
# ..     ...          ...    ...        ...        ...             ...     ...
# 250  False        False  False      False      False           False   False
# 251  False        False  False      False      False           False   False
# 252  False        False  False      False      False           False   False
# 253  False        False  False      False      False           False   False
# 254  False        False  False      False      False           False   False
#
#      state  region
# 0    False   False
# ...

# %% [markdown]
# # count the empty values in each column

# %%
df.isnull().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# dtype: int64

# %% [markdown]
# # Replace -1 with null value

# %%
df.fillna(-1,inplace=True)
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %% [markdown]
# # count the empty values in each column after replacing null values with -1

# %%
df.isnull().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            0
# dtype: int64

# %% [markdown]
# # Use value_count method for diet column and display the count

# %%
df["diet"].value_counts()
# Out:
# vegetarian        226
# non vegetarian     29
# Name: diet, dtype: int64

# %% [markdown]
# # Filter the 'flavor_profile' column for the value "sweet" and 'course' columns value equal to 'desert'

# %%
flvdf = df.loc[(df['flavor_profile'] == 'sweet') & 
              (df['course']=='dessert')] 
flvdf
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %% [markdown]
# # sort 'cook_time' column in ascending order

# %%
newdf=df.sort_values('cook_time',ascending=True)
newdf
# Out:
#                name                                        ingredients  \
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
# 152         Poriyal       Chana dal, urad dal, beans, coconut, mustard
# 167     Kolim Jawla  Baingan, fish, coconut oil, fresh coconut, ginger
# 172      Bombil fry  Bombay duck, malvani masala, rice flour, bomba...
# 134  Keerai masiyal  Urad dal, curry leaves, sugar, mustard seeds, ...
# ..              ...                                                ...
# 144     Masala Dosa  Chana dal, urad dal, potatoes, idli rice, thic...
# 27          Malapua         Yoghurt, refined flour, ghee, fennel seeds
# 114     Pindi chana   Fennel, tea bags, tomato, kasuri methi, cinnamon
# 75          Biryani  Chicken thighs, basmati rice, star anise, swee...
# 62        Shrikhand                     Curd, sugar, saffron, cardamom
#
#                diet  prep_time  cook_time flavor_profile       course  \
# ...

# %% [markdown]
# # Display only the following columns with values: cook_time,name(Ascending)

# %%
newdf[['cook_time','name']]
# Out:
#      cook_time            name
# 254         -1          Pinaca
# 152         -1         Poriyal
# 167         -1     Kolim Jawla
# 172         -1      Bombil fry
# 134         -1  Keerai masiyal
# ..         ...             ...
# 144         90     Masala Dosa
# 27         120         Malapua
# 114        120     Pindi chana
# 75         120         Biryani
# 62         720       Shrikhand
#
# [255 rows x 2 columns]

# %% [markdown]
# # Descending Cook Time

# %%
descend=df.sort_values('cook_time',ascending=False)
descend
# Out:
#             name                                        ingredients  \
# 62     Shrikhand                     Curd, sugar, saffron, cardamom
# 27       Malapua         Yoghurt, refined flour, ghee, fennel seeds
# 75       Biryani  Chicken thighs, basmati rice, star anise, swee...
# 114  Pindi chana   Fennel, tea bags, tomato, kasuri methi, cinnamon
# 34      Rasgulla                            Chhena, sugar, cardamom
# ..           ...                                                ...
# 65   Pork Bharta   Boiled pork, onions, chillies, ginger and garlic
# 223  Kumol Sawul                       Rice, eggs, carrot, beetroot
# 220   Cheera Doi                                  Rice, mango, curd
# 213   Mag Dhokli      Moong beans, jaggery, red chillies, oil, salt
# 254       Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 62       vegetarian         10        720          sweet      dessert
# ...

# %% [markdown]
# ##  Visualise the plot using matplotlib or seaborn with the following columns:                                x= cook_time('cook_time' column values should be in descending order)y= name

# %%
sns.catplot(x="cook_time", y="name", kind="bar", data=descend)

# %% [markdown]
# # Display countplot in seaborn for flavor_profile column

# %%
flvcount=sns.countplot(x="flavor_profile", data=df)
flvcount
# Out:
# <AxesSubplot:xlabel='flavor_profile', ylabel='count'>
